# %%
from csv import reader

# %%
dataset = list(reader(open("potus_visitors_2015.csv")))

# %%
header = dataset[0]
dataset = dataset[1:]

# %%
dataset[-1][2]
# Out:
# '12/18/2015 16:30'

# %%
dataset[-1][3]
# Out:
# '12/18/2015 23:59'

# %%
"month/day/year Hour-24:Mins"

# %%
date_format = "%m/%d/%Y %H:%M"

# %%
import datetime as dt

# %%
date = "12/18/2015 16:30"

# %%
date
# Out:
# '12/18/2015 16:30'

# %%
dt.datetime.strptime(date,date_format)
# Out:
# datetime.datetime(2015, 12, 18, 16, 30)

# %%
print(dt.datetime.strptime(date,date_format))
# Out:
# 2015-12-18 16:30:00

# %%
date = dt.datetime.strptime(date,date_format)

# %%
date.year
# Out:
# 2015

# %%
date.day
# Out:
# 18

# %%
date.month
# Out:
# 12

# %%
date.hour
# Out:
# 16

# %%
date.minute
# Out:
# 30

# %%
date_format = "%m/%d/%Y %H:%M"

for i in dataset:
    i[2] = dt.datetime.strptime(i[2],date_format)
    i[3] = dt.datetime.strptime(i[3],date_format)
    print(i[2],i[3])
# Out:
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# ...

# %%
dataset[-1][2].strftime("%B %A %d, %Y")
# Out:
# 'December Friday 18, 2015'

# %%
dataset[-1][2].strftime("%A %B %d at %I:%M %p")
# Out:
# 'Friday December 18 at 04:30 PM'

# %%
{"January": 1234, }

# %%
visitors = {}

for i in dataset:
    month = i[2].strftime("%B")
    if month not in visitors:
        visitors[month] = 1
    else:
        visitors[month] += 1

# %%
visitors
# Out:
# {'January': 1248,
#  'February': 2165,
#  'March': 2262,
#  'April': 4996,
#  'May': 3013,
#  'June': 7743,
#  'July': 2930,
#  'August': 1350,
#  'September': 4416,
#  'October': 3669,
#  'November': 1133,
#  'December': 13029}

# %%
for i in dataset:
    if i[2].month == 1:
        print(i[2])
# Out:
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# 2015-01-06 09:30:00
# ...

# %%
# TimeDelta

# %%
current_date = dt.datetime.now()
current_date
# Out:
# datetime.datetime(2023, 5, 14, 18, 0, 42, 575826)

# %%
current_date.year
# Out:
# 2023

# %%
new_batch = dt.timedelta(days = 25)
new_batch
# Out:
# datetime.timedelta(days=25)

# %%
print(current_date + new_batch)
# Out:
# 2023-06-08 18:00:42.575826

# %%
print(current_date - new_batch)
# Out:
# 2023-04-19 18:00:42.575826
